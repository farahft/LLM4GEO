# %%
from rdflib import Graph, URIRef, Literal
from rdflib.namespace import RDF
from neo4j import GraphDatabase

# Neo4j credentials
NEO4J_URI = "bolt://localhost:7687"  # Adjust if needed
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "thelastofus"

# %%
from rdflib import Graph, URIRef, Literal
from rdflib.namespace import RDF

# Load the RDF file
def load_rdf(file_path):
    g = Graph()
    g.parse(file_path, format='xml')  # Adjust format if necessary (e.g., 'turtle', 'n3')
    return g

# Inspect all unique URIs (Subjects, Predicates, Objects) in the RDF graph
def inspect_uris(g):
    subjects = set()
    predicates = set()
    objects = set()

    # Iterate through all triples
    for s, p, o in g:
        subjects.add(str(s))   # Add subject URIs
        predicates.add(str(p)) # Add predicate URIs
        objects.add(str(o))    # Add object URIs or literals

    # Print all unique URIs found
    print("Subjects (Entities/Individuals):")
    for s in subjects:
        print(s)
    
    print("\nPredicates (Properties/Relationships):")
    for p in predicates:
        print(p)
    
    print("\nObjects (Values/Other Entities):")
    for o in objects:
        print(o)

# Inspect the classes (types) defined in the RDF graph
def inspect_classes(g):
    classes = set()

    # Look for rdf:type relationships
    for s, p, o in g:
        if p == RDF.type and isinstance(o, URIRef):
            classes.add(str(o))

    print("Classes (Types):")
    for cls in classes:
        print(cls)

# Inspect individuals and their associated types (rdf:type)
def inspect_individuals(g):
    individuals = set()

    for s, p, o in g:
        if p == RDF.type and isinstance(o, URIRef):
            individuals.add((str(s), str(o)))  # Store (individual, class) pairs

    print("Individuals and Their Types:")
    for ind, cls in individuals:
        print(f"Individual: {ind}, Class: {cls}")

# Inspect relationships between individuals (predicates)
def inspect_relationships(g):
    relationships = set()

    for s, p, o in g:
        if isinstance(p, URIRef) and isinstance(o, URIRef):
            relationships.add((str(s), str(p), str(o)))  # Store (subject, predicate, object)

    print("Relationships:")
    for subj, pred, obj in relationships:
        print(f"Subject: {subj}, Predicate: {pred}, Object: {obj}")

# Main function to inspect the RDF graph and display the results
def inspect_ontology(g):
    print("Inspecting URIs in the RDF Graph...\n")
    inspect_uris(g)
    
    print("\nInspecting Classes...\n")
    inspect_classes(g)
    
    print("\nInspecting Individuals and Their Types...\n")
    inspect_individuals(g)
    
    print("\nInspecting Relationships...\n")
    inspect_relationships(g)

# Main execution workflow
def main(rdf_file):
    g = load_rdf(rdf_file)
    inspect_ontology(g)

# Provide the path to your RDF file
rdf_file = "onto.rdf"  # Change this to your RDF file's path
main(rdf_file)
# Out:
# Inspecting URIs in the RDF Graph...
#
# Subjects (Entities/Individuals):
# http://www.semanticweb.org/geopoliFirst#Euromaidan_Protests
# http://www.semanticweb.org/geopoliFirst#Length/Extent
# http://www.semanticweb.org/geopoliFirst#FACES_PROTECTION_FROM
# http://www.semanticweb.org/geopoliFirst#UN_Security_Council
# http://www.semanticweb.org/geopoliFirst#Vladimir_Putin
# http://www.semanticweb.org/geopoliFirst#Pollution_Levels
# http://www.semanticweb.org/geopoliFirst#President
# http://www.semanticweb.org/geopoliFirst#Viktor_Yanukovych
# http://www.semanticweb.org/geopoliFirst#capital
# http://www.semanticweb.org/geopoliFirst#Timber
# http://www.semanticweb.org/geopoliFirst#Environmental_Factors
# http://www.semanticweb.org/geopoliFirst#FACES_GEOPOLITICAL_CHALLENGE
# http://www.semanticweb.org/geopoliFirst#Technology
# http://www.semanticweb.org/geopoliFirst#Ukrainian_Military
# http://www.semanticweb.org/geopoliFirst#sugar_beets
# http://www.semanticweb.org/geopoliFirst#SEEKING_MEMBERSHIP
# http://www.semanticweb.org/geopoliFirst#HAS_INFRASTRUCTURE
# http://www.semanticweb.org/geopoliFirst#Tropical
# http://www.semanticweb.org/geopoliFirst#Discontinuous_Borders
# http://www.semanticweb.org/geopoliFirst#Elevation_Range
# http://www.semanticweb.org/geopoliFirst#artillery
# http://www.semanticweb.org/geopoliFirst#INVOLVED_IN
# http://www.semanticweb.org/geopoliFirst#Military
# http://www.semanticweb.org/geopoliFirst#Agriculture
# http://www.semanticweb.org/geopoliFirst#FACES
# http://www.semanticweb.org/geopoliFirst#Russia
# http://www.semanticweb.org/geopoliFirst#Black_Sea
# http://www.semanticweb.org/geopoliFirst#FACES_BORDER_CHALLENGE
# http://www.semanticweb.org/geopoliFirst/CONTROLS
# http://www.semanticweb.org/geopoliFirst#Atlantic_Ocean
# http://www.semanticweb.org/geopoliFirst#Concept
# http://www.semanticweb.org/geopoliFirst#Titanium
# http://www.semanticweb.org/geopoliFirst#imported_From
# http://www.semanticweb.org/geopoliFirst#OCCURRED_AT
# http://www.semanticweb.org/geopoliFirst#Sulfur
# http://www.semanticweb.org/geopoliFirst#Himalayas
# http://www.semanticweb.org/geopoliFirst#Volodymyr_Zelensky
# http://www.semanticweb.org/geopoliFirst#STARTED_WAR
# http://www.semanticweb.org/geopoliFirst#Bucharest_Summit_2008
# http://www.semanticweb.org/geopoliFirst#Defense_Systems
# http://www.semanticweb.org/geopoliFirst#HAS_EQUIPMENT
# http://www.semanticweb.org/geopoliFirst#Continental
# http://www.semanticweb.org/geopoliFirst#Cause
# http://www.semanticweb.org/geopoliFirst#Impact
# http://www.semanticweb.org/geopoliFirst#Mercury
# http://www.semanticweb.org/geopoliFirst#gdp
# http://www.semanticweb.org/geopoliFirst#Crimea
# http://www.semanticweb.org/geopoliFirst#NATO
# http://www.semanticweb.org/geopoliFirst#Person
# http://www.semanticweb.org/geopoliFirst#Ukrainian_Sovereignty
# http://www.semanticweb.org/geopoliFirst#Iron_Ore
# http://www.semanticweb.org/geopoliFirst#Population_density
# http://www.semanticweb.org/geopoliFirst#Arctic_Ocean
# http://www.semanticweb.org/geopoliFirst#PARTICIPATED_IN
# http://www.semanticweb.org/geopoliFirst#Manganese
# http://www.semanticweb.org/geopoliFirst#Country
# http://www.semanticweb.org/geopoliFirst#PERCEIVES_THREAT_FROM
# http://www.semanticweb.org/geopoliFirst#Turkish_Straits
# http://www.semanticweb.org/geopoliFirst#International_Trade_Sea_Lanes
# http://www.semanticweb.org/geopoliFirst#Event
# http://www.semanticweb.org/geopoliFirst#Objective
# http://www.semanticweb.org/geopoliFirst#LAUNCHED_WAR_ON
# http://www.semanticweb.org/geopoliFirst#Ukrain
# http://www.semanticweb.org/geopoliFirst#Grain_Corn
# http://www.semanticweb.org/geopoliFirst#Economic_Feature
# http://www.semanticweb.org/geopoliFirst#Graphite
# http://www.semanticweb.org/geopoliFirst#PERCEIVES_AS_HISTORICAL_LANDS
# N9e526473d82549909999c8f6cbff0ef0
# http://www.semanticweb.org/geopoliFirst#DEPLOYED
# http://www.semanticweb.org/geopoliFirst#Resources
# http://www.semanticweb.org/geopoliFirst#Natural_Resource_Management
# http://www.semanticweb.org/geopoliFirst#LEADS
# http://www.semanticweb.org/geopoliFirst#LED_BY
# http://www.semanticweb.org/geopoliFirst#PROTESTED_IN
# http://www.semanticweb.org/geopoliFirst/HAS
# http://www.semanticweb.org/geopoliFirst#Location
# http://www.semanticweb.org/geopoliFirst#SIGNED_AGREEMENT_WITH
# http://www.semanticweb.org/geopoliFirst#Canada
# http://www.semanticweb.org/geopoliFirst#SEEKS_NEUTRALITY_OF
# http://www.semanticweb.org/geopoliFirst#population
# http://www.semanticweb.org/geopoliFirst#MOBILIZED
# http://www.semanticweb.org/geopoliFirst#Organization
# http://www.semanticweb.org/geopoliFirst#Currency
# http://www.semanticweb.org/geopoliFirst#PRODUCES
# http://www.semanticweb.org/geopoliFirst#Freshwater_Reserves
# http://www.semanticweb.org/geopoliFirst#Barrier_Type
# http://www.semanticweb.org/geopoliFirst#FACES_PRESSURE_FROM
# http://www.semanticweb.org/geopoliFirst#Active-duty_Personnel
# http://www.semanticweb.org/geopoliFirst#Total_Area
# http://www.semanticweb.org/geopoliFirst#Role
# Nd35c1ecade37497bab3204c3456f32d5
# http://www.semanticweb.org/geopoliFirst#Arable_Land
# http://www.semanticweb.org/geopoliFirst#missile_systems
# http://www.semanticweb.org/geopoliFirst
# http://www.semanticweb.org/geopoliFirst#Demographic
# http://www.semanticweb.org/geopoliFirst#ANNEXED
# N7e4a7a305b274634a2d218fc021f667d
# http://www.semanticweb.org/geopoliFirst#Russian_Weapons
# http://www.semanticweb.org/geopoliFirst#MOVED_TO
# http://www.semanticweb.org/geopoliFirst#Reserve_Forces
# http://www.semanticweb.org/geopoliFirst#Military_Bases
# http://www.semanticweb.org/geopoliFirst#CONSIDERS_USE_OF
# http://www.semanticweb.org/geopoliFirst#Gold
# http://www.semanticweb.org/geopoliFirst#PREPARES_FOR
# http://www.semanticweb.org/geopoliFirst#FIGHTS_FOR
# http://www.semanticweb.org/geopoliFirst#Notable_Features
# http://www.semanticweb.org/geopoliFirst#Mountainous
# http://www.semanticweb.org/geopoliFirst#Total_Victory_Over_Ukraine
# http://www.semanticweb.org/geopoliFirst#Tsunami
# http://www.semanticweb.org/geopoliFirst#POSSESSES_NUCLEAR_ARMS
# http://www.semanticweb.org/geopoliFirst#PASSES_ON_DIRECT_INTERVENTION
# http://www.semanticweb.org/geopoliFirst#wheat
# http://www.semanticweb.org/geopoliFirst#Earthquake
# http://www.semanticweb.org/geopoliFirst#HAS_EXPORT_PARTNER
# http://www.semanticweb.org/geopoliFirst#Geographical_Space
# http://www.semanticweb.org/geopoliFirst#Government
# http://www.semanticweb.org/geopoliFirst#domestic
# http://www.semanticweb.org/geopoliFirst#Russian_Military
# http://www.semanticweb.org/geopoliFirst#HAS_IMPORT_PARTNER
# http://www.semanticweb.org/geopoliFirst#Baltic_sea
# http://www.semanticweb.org/geopoliFirst#China
# http://www.semanticweb.org/geopoliFirst#Plain
# http://www.semanticweb.org/geopoliFirst#Coal
# http://www.semanticweb.org/geopoliFirst#TARGETED_AT
# http://www.semanticweb.org/geopoliFirst#Nuclear_Arsenal
# http://www.semanticweb.org/geopoliFirst/INCLUDES
# http://www.semanticweb.org/geopoliFirst#Government_Type
# http://www.semanticweb.org/geopoliFirst#EU
# http://www.semanticweb.org/geopoliFirst#Territorial_Annexation_of_Ukraine
# http://www.semanticweb.org/geopoliFirst#Region
# http://www.semanticweb.org/geopoliFirst#Imported_Weapons
# http://www.semanticweb.org/geopoliFirst#Buffer-State_Status_for_Ukraine
# http://www.semanticweb.org/geopoliFirst#Russian_Government
# http://www.semanticweb.org/geopoliFirst#Eurasian_Flatlands
# http://www.semanticweb.org/geopoliFirst#Caucasus
# http://www.semanticweb.org/geopoliFirst#Donbass_War
# http://www.semanticweb.org/geopoliFirst#Oil
# http://www.semanticweb.org/geopoliFirst#HAS_RESOURCE
# http://www.semanticweb.org/geopoliFirst#Protected_Areas
# http://www.semanticweb.org/geopoliFirst#land_systems
# http://www.semanticweb.org/geopoliFirst#Major_rivers_and_water_bodies
# http://www.semanticweb.org/geopoliFirst#Rimland
# http://www.semanticweb.org/geopoliFirst#RELIES_ON
# http://www.semanticweb.org/geopoliFirst#Seasonal_Variability
# http://www.semanticweb.org/geopoliFirst#IS_PART_OF
# http://www.semanticweb.org/geopoliFirst#FACES_BARRIER_FROM
# http://www.semanticweb.org/geopoliFirst#Nickel
# http://www.semanticweb.org/geopoliFirst#Salt
# http://www.semanticweb.org/geopoliFirst#Operational_Nuclear_Reactors
# http://www.semanticweb.org/geopoliFirst#Gas
# http://www.semanticweb.org/geopoliFirst#SEEKS_OBJECTIVE
# http://www.semanticweb.org/geopoliFirst#USED_ON
# http://www.semanticweb.org/geopoliFirst#description
# http://www.semanticweb.org/geopoliFirst#Sugar_Beets
# http://www.semanticweb.org/geopoliFirst#air_systems
# http://www.semanticweb.org/geopoliFirst#UN_Security
# http://www.semanticweb.org/geopoliFirst#Intensified_Combat
# http://www.semanticweb.org/geopoliFirst#Carpathian_Mountains
# http://www.semanticweb.org/geopoliFirst#Russian_Intelligence
# http://www.semanticweb.org/geopoliFirst#Agency
# http://www.semanticweb.org/geopoliFirst#PERCEIVES_WEAKNESS_IN
# http://www.semanticweb.org/geopoliFirst#ISSUES_COMMAND_TO
# http://www.semanticweb.org/geopoliFirst#Military_Alliances
# http://www.semanticweb.org/geopoliFirst#Pacific_Ocean
# http://www.semanticweb.org/geopoliFirst#Temperate
# http://www.semanticweb.org/geopoliFirst#West
# http://www.semanticweb.org/geopoliFirst#Accessibility
# http://www.semanticweb.org/geopoliFirst#Infrastructure
# http://www.semanticweb.org/geopoliFirst#Strategic_Minerals
# http://www.semanticweb.org/geopoliFirst#sea_systems
# http://www.semanticweb.org/geopoliFirst#HAS_NUCLEAR_REACTORS
# http://www.semanticweb.org/geopoliFirst#Military_Expenditure
# http://www.semanticweb.org/geopoliFirst#Railways_and_Roads
# http://www.semanticweb.org/geopoliFirst#Domestically_Produced_Weapons
# http://www.semanticweb.org/geopoliFirst#INFLUENCES
# http://www.semanticweb.org/geopoliFirst#POSSESSES
# http://www.semanticweb.org/geopoliFirst#FACES_INTERNAL_PROBLEM
#
# Predicates (Properties/Relationships):
# http://www.semanticweb.org/geopoliFirst#Length/Extent
# http://www.w3.org/2002/07/owl#annotatedProperty
# http://www.semanticweb.org/geopoliFirst#President
# http://www.w3.org/2000/01/rdf-schema#comment
# http://www.semanticweb.org/geopoliFirst#capital
# http://www.semanticweb.org/geopoliFirst#FACES_GEOPOLITICAL_CHALLENGE
# http://www.semanticweb.org/geopoliFirst#SEEKING_MEMBERSHIP
# http://www.semanticweb.org/geopoliFirst#HAS_INFRASTRUCTURE
# http://www.semanticweb.org/geopoliFirst#artillery
# http://www.semanticweb.org/geopoliFirst#Elevation_Range
# http://www.semanticweb.org/geopoliFirst#INVOLVED_IN
# http://www.semanticweb.org/geopoliFirst#Agriculture
# http://www.semanticweb.org/geopoliFirst#FACES
# http://www.semanticweb.org/geopoliFirst#FACES_BORDER_CHALLENGE
# http://www.semanticweb.org/geopoliFirst/CONTROLS
# http://www.semanticweb.org/geopoliFirst#imported_From
# http://www.semanticweb.org/geopoliFirst#STARTED_WAR
# http://www.semanticweb.org/geopoliFirst#Impact
# http://www.semanticweb.org/geopoliFirst#Cause
# http://www.semanticweb.org/geopoliFirst#gdp
# http://www.semanticweb.org/geopoliFirst#Population_density
# http://www.semanticweb.org/geopoliFirst#PARTICIPATED_IN
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.semanticweb.org/geopoliFirst#PERCEIVES_THREAT_FROM
# http://www.semanticweb.org/geopoliFirst#LAUNCHED_WAR_ON
# http://www.semanticweb.org/geopoliFirst#PERCEIVES_AS_HISTORICAL_LANDS
# http://www.semanticweb.org/geopoliFirst#DEPLOYED
# http://www.semanticweb.org/geopoliFirst#LEADS
# http://www.semanticweb.org/geopoliFirst#LED_BY
# http://www.semanticweb.org/geopoliFirst#Location
# http://www.semanticweb.org/geopoliFirst#PROTESTED_IN
# http://www.semanticweb.org/geopoliFirst/HAS
# http://www.semanticweb.org/geopoliFirst#SIGNED_AGREEMENT_WITH
# http://www.semanticweb.org/geopoliFirst#SEEKS_NEUTRALITY_OF
# http://www.semanticweb.org/geopoliFirst#population
# http://www.semanticweb.org/geopoliFirst#MOBILIZED
# http://www.semanticweb.org/geopoliFirst#Currency
# http://www.semanticweb.org/geopoliFirst#PRODUCES
# http://www.semanticweb.org/geopoliFirst#Barrier_Type
# http://www.semanticweb.org/geopoliFirst#FACES_PRESSURE_FROM
# http://www.semanticweb.org/geopoliFirst#Total_Area
# http://www.semanticweb.org/geopoliFirst#missile_systems
# http://www.semanticweb.org/geopoliFirst#ANNEXED
# http://www.semanticweb.org/geopoliFirst#MOVED_TO
# http://www.semanticweb.org/geopoliFirst#PREPARES_FOR
# http://www.semanticweb.org/geopoliFirst#CONSIDERS_USE_OF
# http://www.semanticweb.org/geopoliFirst#FIGHTS_FOR
# http://www.semanticweb.org/geopoliFirst#Notable_Features
# http://www.semanticweb.org/geopoliFirst#POSSESSES_NUCLEAR_ARMS
# http://www.semanticweb.org/geopoliFirst#PASSES_ON_DIRECT_INTERVENTION
# http://www.semanticweb.org/geopoliFirst#HAS_EXPORT_PARTNER
# http://www.semanticweb.org/geopoliFirst#domestic
# http://www.semanticweb.org/geopoliFirst#HAS_IMPORT_PARTNER
# http://www.semanticweb.org/geopoliFirst#TARGETED_AT
# http://www.semanticweb.org/geopoliFirst#Government_Type
# http://www.semanticweb.org/geopoliFirst/INCLUDES
# http://www.semanticweb.org/geopoliFirst#Region
# http://www.semanticweb.org/geopoliFirst#HAS_RESOURCE
# http://www.semanticweb.org/geopoliFirst#land_systems
# http://www.w3.org/2002/07/owl#annotatedSource
# http://www.semanticweb.org/geopoliFirst#Major_rivers_and_water_bodies
# http://www.semanticweb.org/geopoliFirst#RELIES_ON
# http://www.semanticweb.org/geopoliFirst#Seasonal_Variability
# http://www.semanticweb.org/geopoliFirst#IS_PART_OF
# http://www.semanticweb.org/geopoliFirst#FACES_BARRIER_FROM
# http://www.semanticweb.org/geopoliFirst#SEEKS_OBJECTIVE
# http://www.semanticweb.org/geopoliFirst#description
# http://www.semanticweb.org/geopoliFirst#air_systems
# http://www.semanticweb.org/geopoliFirst#UN_Security
# http://www.semanticweb.org/geopoliFirst#ISSUES_COMMAND_TO
# http://www.semanticweb.org/geopoliFirst#PERCEIVES_WEAKNESS_IN
# http://www.w3.org/2002/07/owl#annotatedTarget
# http://www.semanticweb.org/geopoliFirst#sea_systems
# http://www.semanticweb.org/geopoliFirst#HAS_NUCLEAR_REACTORS
# http://www.semanticweb.org/geopoliFirst#INFLUENCES
# http://www.semanticweb.org/geopoliFirst#POSSESSES
# http://www.semanticweb.org/geopoliFirst#FACES_INTERNAL_PROBLEM
#
# Objects (Values/Other Entities):
# World's Highest Range
# http://www.semanticweb.org/geopoliFirst#Euromaidan_Protests
# length: 22407
# http://www.semanticweb.org/geopoliFirst#UN_Security_Council
# http://www.w3.org/2002/07/owl#DatatypeProperty
# Federal Parliamentary
# http://www.semanticweb.org/geopoliFirst#Viktor_Yanukovych
# Pacific Ocean, South China Sea, Indian Ocean.
# Russia
# http://www.semanticweb.org/geopoliFirst#Timber
# http://www.semanticweb.org/geopoliFirst#Environmental_Factors
# Tectonic Movement
# http://www.semanticweb.org/geopoliFirst#Technology
# http://www.w3.org/2002/07/owl#NamedIndividual
# http://www.semanticweb.org/geopoliFirst#Ukrainian_Military
# Unitary
# http://www.semanticweb.org/geopoliFirst#Discontinuous_Borders
# http://www.semanticweb.org/geopoliFirst#Military
# http://www.semanticweb.org/geopoliFirst#Russia
# http://www.semanticweb.org/geopoliFirst#FACES_BORDER_CHALLENGE
# Not specified
# http://www.semanticweb.org/geopoliFirst#Concept
# http://www.semanticweb.org/geopoliFirst#Titanium
# http://www.semanticweb.org/geopoliFirst#Sulfur
# North of Russia
# Yes
# Mountain
# Himalayan mountains, plateaus
# Ruble
# http://www.semanticweb.org/geopoliFirst#Mercury
# Monsoonal
# 2,400 km
# http://www.w3.org/2002/07/owl#Class
# http://www.semanticweb.org/geopoliFirst#Crimea
# http://www.semanticweb.org/geopoliFirst#NATO
# http://www.semanticweb.org/geopoliFirst#Person
# http://www.semanticweb.org/geopoliFirst#Ukrainian_Sovereignty
# http://www.semanticweb.org/geopoliFirst#Arctic_Ocean
# president of Ukraine
# Dnieper River (tributary)
# 3.6
# 0 m to 8,848 m (Mount Everest)
# http://www.semanticweb.org/geopoliFirst#Country
# http://www.semanticweb.org/geopoliFirst#Turkish_Straits
# http://www.semanticweb.org/geopoliFirst#International_Trade_Sea_Lanes
# http://www.semanticweb.org/geopoliFirst#Event
# 1400000000
# Beijing
# http://www.w3.org/2002/07/owl#Ontology
# http://www.semanticweb.org/geopoliFirst#Objective
# Low to medium
# http://www.semanticweb.org/geopoliFirst#Ukrain
# http://www.semanticweb.org/geopoliFirst#Grain_Corn
# Approximately 200,000 km² (range)
# http://www.semanticweb.org/geopoliFirst#Economic_Feature
# http://www.semanticweb.org/geopoliFirst#Resources
# Eastern Europe
# Approximately 20,000,000 km² (spanning multiple countries).
# Approximately 440,000 km² (estimate).
# Tisza River
# length : 5581
# http://www.semanticweb.org/geopoliFirst#Organization
# http://www.semanticweb.org/geopoliFirst#Freshwater_Reserves
# Federal
# Kura River, Caspian Sea.
# Low to medium (varies by subregion).
# Internal problem causing resentment
# Facilitates and hinders transatlantic trade and migration
# http://www.semanticweb.org/geopoliFirst#Arable_Land
# Approximately 10,000,000 km² (estimate)
# Vast plains
# Moscow
# Putin
# http://www.semanticweb.org/geopoliFirst#Russian_Weapons
# North America
# 144 million
# East Asia
# 436,402 km²
# Impacts trade, cultural exchange
# Dry winters, warm summers
# http://www.semanticweb.org/geopoliFirst#Gold
# Well-developed, increases accessibility
# Crucial for Ukraine's access to international sea lanes
# http://www.semanticweb.org/geopoliFirst#Total_Victory_Over_Ukraine
# Ocean
# 5.3
# kyiv
# http://www.semanticweb.org/geopoliFirst#wheat
# Rich Soil
# http://www.semanticweb.org/geopoliFirst#Geographical_Space
# http://www.semanticweb.org/geopoliFirst#Government
# http://www.semanticweb.org/geopoliFirst#Russian_Military
# http://www.semanticweb.org/geopoliFirst#China
# 38000000
# http://www.semanticweb.org/geopoliFirst#Coal
# http://www.w3.org/2002/07/owl#Axiom
# http://www.semanticweb.org/geopoliFirst#EU
# Canadian Dollar
# http://www.semanticweb.org/geopoliFirst#Territorial_Annexation_of_Ukraine
# 41000000
# Renminbi (Yuan)
# http://www.semanticweb.org/geopoliFirst#Russian_Government
# http://www.semanticweb.org/geopoliFirst#Imported_Weapons
# http://www.semanticweb.org/geopoliFirst#Buffer-State_Status_for_Ukraine
# http://www.semanticweb.org/geopoliFirst#Region
# Medium to high in urban centers.
# http://www.semanticweb.org/geopoliFirst#Eurasian_Flatlands
# http://www.semanticweb.org/geopoliFirst#Donbass_War
# http://www.semanticweb.org/geopoliFirst#Caucasus
# http://www.w3.org/2002/07/owl#ObjectProperty
# http://www.semanticweb.org/geopoliFirst#Oil
# Submarine Earthquakes
# http://www.semanticweb.org/geopoliFirst#Rimland
# Eastern Europe, Asia
# Provides military protection
# Ottawa
# Acts as a natural defense and influences climate
# http://www.semanticweb.org/geopoliFirst#Salt
# Low (sparsely populated).
# http://www.semanticweb.org/geopoliFirst#Operational_Nuclear_Reactors
# Iran, North Korea
# http://www.semanticweb.org/geopoliFirst#Gas
# http://www.semanticweb.org/geopoliFirst#Sugar_Beets
# president of Russia
# Global trade routes accessible via Turkish Straits
# Zelensky
# 0 m to 1,000 m
# http://www.semanticweb.org/geopoliFirst#Intensified_Combat
# http://www.semanticweb.org/geopoliFirst#Carpathian_Mountains
# http://www.semanticweb.org/geopoliFirst#Russian_Intelligence
# http://www.semanticweb.org/geopoliFirst#Agency
# Between Ukraine and international trade routes
# Far East Russia
# http://www.semanticweb.org/geopoliFirst#West
# http://www.semanticweb.org/geopoliFirst#Infrastructure
# Distinct seasons
# http://www.semanticweb.org/geopoliFirst#Strategic_Minerals
# Dnieper River, Volga River, Ural River
# Socialist Republic
# true
# http://www.semanticweb.org/geopoliFirst#Railways_and_Roads
# Hryvnia
# http://www.semanticweb.org/geopoliFirst#FACES_INTERNAL_PROBLEM
#
# Inspecting Classes...
#
# Classes (Types):
# http://www.w3.org/2002/07/owl#ObjectProperty
# http://www.w3.org/2002/07/owl#DatatypeProperty
# http://www.w3.org/2002/07/owl#Class
# http://www.semanticweb.org/geopoliFirst#Person
# http://www.semanticweb.org/geopoliFirst#Environmental_Factors
# http://www.semanticweb.org/geopoliFirst#Technology
# http://www.w3.org/2002/07/owl#NamedIndividual
# http://www.semanticweb.org/geopoliFirst#Country
# http://www.semanticweb.org/geopoliFirst#Event
# http://www.w3.org/2002/07/owl#Ontology
# http://www.semanticweb.org/geopoliFirst#Objective
# http://www.semanticweb.org/geopoliFirst#Economic_Feature
# http://www.semanticweb.org/geopoliFirst#Military
# http://www.semanticweb.org/geopoliFirst#Resources
# http://www.semanticweb.org/geopoliFirst#Geographical_Space
# http://www.semanticweb.org/geopoliFirst#Government
# http://www.semanticweb.org/geopoliFirst#Agency
# http://www.w3.org/2002/07/owl#Axiom
# http://www.semanticweb.org/geopoliFirst#Infrastructure
# http://www.semanticweb.org/geopoliFirst#Organization
# http://www.semanticweb.org/geopoliFirst#Concept
# http://www.semanticweb.org/geopoliFirst#Region
#
# Inspecting Individuals and Their Types...
#
# Individuals and Their Types:
# Individual: http://www.semanticweb.org/geopoliFirst#Impact, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Military, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Agriculture, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#imported_From, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Russian_Government, Class: http://www.semanticweb.org/geopoliFirst#Government
# Individual: http://www.semanticweb.org/geopoliFirst#USED_ON, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#EU, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#MOVED_TO, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Oil, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#Territorial_Annexation_of_Ukraine, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#HAS_EQUIPMENT, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#HAS_INFRASTRUCTURE, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Russian_Weapons, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Domestically_Produced_Weapons, Class: http://www.semanticweb.org/geopoliFirst#Military
# Individual: http://www.semanticweb.org/geopoliFirst#Continental, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Russian_Military, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Mercury, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#PROTESTED_IN, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#UN_Security, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#MOBILIZED, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Manganese, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Caucasus, Class: http://www.semanticweb.org/geopoliFirst#Geographical_Space
# Individual: http://www.semanticweb.org/geopoliFirst/CONTROLS, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#ISSUES_COMMAND_TO, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Country, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#NATO, Class: http://www.semanticweb.org/geopoliFirst#Organization
# Individual: http://www.semanticweb.org/geopoliFirst#Viktor_Yanukovych, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Eurasian_Flatlands, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#SIGNED_AGREEMENT_WITH, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#wheat, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#IS_PART_OF, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Euromaidan_Protests, Class: http://www.semanticweb.org/geopoliFirst#Event
# Individual: http://www.semanticweb.org/geopoliFirst#POSSESSES_NUCLEAR_ARMS, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Gold, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Arctic_Ocean, Class: http://www.semanticweb.org/geopoliFirst#Geographical_Space
# Individual: http://www.semanticweb.org/geopoliFirst#Cause, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Salt, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#TARGETED_AT, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#PREPARES_FOR, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Atlantic_Ocean, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Rimland, Class: http://www.semanticweb.org/geopoliFirst#Geographical_Space
# Individual: http://www.semanticweb.org/geopoliFirst#Donbass_War, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Location, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#FACES_BORDER_CHALLENGE, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#FIGHTS_FOR, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Oil, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#UN_Security_Council, Class: http://www.semanticweb.org/geopoliFirst#Organization
# Individual: http://www.semanticweb.org/geopoliFirst#capital, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Active-duty_Personnel, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Salt, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#CONSIDERS_USE_OF, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#population, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Region, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#NATO, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Currency, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Bucharest_Summit_2008, Class: http://www.semanticweb.org/geopoliFirst#Event
# Individual: http://www.semanticweb.org/geopoliFirst#Total_Area, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Natural_Resource_Management, Class: http://www.semanticweb.org/geopoliFirst#Environmental_Factors
# Individual: http://www.semanticweb.org/geopoliFirst#Eurasian_Flatlands, Class: http://www.semanticweb.org/geopoliFirst#Geographical_Space
# Individual: http://www.semanticweb.org/geopoliFirst#Intensified_Combat, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Protected_Areas, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Black_Sea, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Ukrainian_Sovereignty, Class: http://www.semanticweb.org/geopoliFirst#Concept
# Individual: http://www.semanticweb.org/geopoliFirst#Buffer-State_Status_for_Ukraine, Class: http://www.semanticweb.org/geopoliFirst#Objective
# Individual: http://www.semanticweb.org/geopoliFirst/INCLUDES, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Person, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Natural_Resource_Management, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Crimea, Class: http://www.semanticweb.org/geopoliFirst#Region
# Individual: http://www.semanticweb.org/geopoliFirst#Russia, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Nickel, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: N9e526473d82549909999c8f6cbff0ef0, Class: http://www.w3.org/2002/07/owl#Axiom
# Individual: http://www.semanticweb.org/geopoliFirst#FACES, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#UN_Security_Council, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Accessibility, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Objective, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#FACES_INTERNAL_PROBLEM, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#SEEKS_NEUTRALITY_OF, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#West, Class: http://www.semanticweb.org/geopoliFirst#Region
# Individual: http://www.semanticweb.org/geopoliFirst#Seasonal_Variability, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Volodymyr_Zelensky, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Operational_Nuclear_Reactors, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#sea_systems, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Ukrainian_Military, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Graphite, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#description, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Viktor_Yanukovych, Class: http://www.semanticweb.org/geopoliFirst#Person
# Individual: http://www.semanticweb.org/geopoliFirst#Baltic_sea, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Russian_Intelligence, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Titanium, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#Freshwater_Reserves, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#President, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Length/Extent, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Operational_Nuclear_Reactors, Class: http://www.semanticweb.org/geopoliFirst#Technology
# Individual: http://www.semanticweb.org/geopoliFirst#Arable_Land, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#Notable_Features, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst, Class: http://www.w3.org/2002/07/owl#Ontology
# Individual: http://www.semanticweb.org/geopoliFirst#Crimea, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Concept, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Discontinuous_Borders, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Russian_Weapons, Class: http://www.semanticweb.org/geopoliFirst#Military
# Individual: http://www.semanticweb.org/geopoliFirst#Russian_Military, Class: http://www.semanticweb.org/geopoliFirst#Military
# Individual: http://www.semanticweb.org/geopoliFirst#LAUNCHED_WAR_ON, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#HAS_IMPORT_PARTNER, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Agency, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Government, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Barrier_Type, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#PARTICIPATED_IN, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Earthquake, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Buffer-State_Status_for_Ukraine, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Gas, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#PASSES_ON_DIRECT_INTERVENTION, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#West, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#LEADS, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Geographical_Space, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Technology, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Russia, Class: http://www.semanticweb.org/geopoliFirst#Country
# Individual: http://www.semanticweb.org/geopoliFirst#Pollution_Levels, Class: http://www.semanticweb.org/geopoliFirst#Environmental_Factors
# Individual: http://www.semanticweb.org/geopoliFirst#Donbass_War, Class: http://www.semanticweb.org/geopoliFirst#Event
# Individual: http://www.semanticweb.org/geopoliFirst#Sugar_Beets, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#Titanium, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#sugar_beets, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#Nuclear_Arsenal, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Ukrain, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Carpathian_Mountains, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Sulfur, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#ANNEXED, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Russian_Intelligence, Class: http://www.semanticweb.org/geopoliFirst#Agency
# Individual: http://www.semanticweb.org/geopoliFirst#Imported_Weapons, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Turkish_Straits, Class: http://www.semanticweb.org/geopoliFirst#Geographical_Space
# Individual: http://www.semanticweb.org/geopoliFirst#artillery, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#OCCURRED_AT, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Discontinuous_Borders, Class: http://www.semanticweb.org/geopoliFirst#Geographical_Space
# Individual: http://www.semanticweb.org/geopoliFirst#Defense_Systems, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Gas, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Russian_Government, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#DEPLOYED, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Iron_Ore, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#RELIES_ON, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Economic_Feature, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Intensified_Combat, Class: http://www.semanticweb.org/geopoliFirst#Event
# Individual: http://www.semanticweb.org/geopoliFirst#Plain, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Railways_and_Roads, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Volodymyr_Zelensky, Class: http://www.semanticweb.org/geopoliFirst#Person
# Individual: N7e4a7a305b274634a2d218fc021f667d, Class: http://www.w3.org/2002/07/owl#Axiom
# Individual: http://www.semanticweb.org/geopoliFirst#gdp, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Sugar_Beets, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Environmental_Factors, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Military_Bases, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Region, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Canada, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#SEEKS_OBJECTIVE, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#land_systems, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Total_Victory_Over_Ukraine, Class: http://www.semanticweb.org/geopoliFirst#Objective
# Individual: http://www.semanticweb.org/geopoliFirst#International_Trade_Sea_Lanes, Class: http://www.semanticweb.org/geopoliFirst#Economic_Feature
# Individual: http://www.semanticweb.org/geopoliFirst#FACES_PROTECTION_FROM, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Turkish_Straits, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#HAS_EXPORT_PARTNER, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Ukrainian_Sovereignty, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#FACES_PRESSURE_FROM, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#PERCEIVES_THREAT_FROM, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Mercury, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#International_Trade_Sea_Lanes, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Tropical, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Carpathian_Mountains, Class: http://www.semanticweb.org/geopoliFirst#Geographical_Space
# Individual: http://www.semanticweb.org/geopoliFirst#Manganese, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#Nickel, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Ukrainian_Military, Class: http://www.semanticweb.org/geopoliFirst#Military
# Individual: http://www.semanticweb.org/geopoliFirst#PERCEIVES_WEAKNESS_IN, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Tsunami, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Resources, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Domestically_Produced_Weapons, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Gold, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#Coal, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#Iron_Ore, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Vladimir_Putin, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#China, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Event, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Railways_and_Roads, Class: http://www.semanticweb.org/geopoliFirst#Infrastructure
# Individual: http://www.semanticweb.org/geopoliFirst#Euromaidan_Protests, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#HAS_NUCLEAR_REACTORS, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Arable_Land, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Major_rivers_and_water_bodies, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#LED_BY, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: Nd35c1ecade37497bab3204c3456f32d5, Class: http://www.w3.org/2002/07/owl#Axiom
# Individual: http://www.semanticweb.org/geopoliFirst#Pollution_Levels, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#STARTED_WAR, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Reserve_Forces, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst/HAS, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Strategic_Minerals, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#PRODUCES, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Total_Victory_Over_Ukraine, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Government_Type, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Canada, Class: http://www.semanticweb.org/geopoliFirst#Country
# Individual: http://www.semanticweb.org/geopoliFirst#INFLUENCES, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Coal, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Grain_Corn, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#INVOLVED_IN, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#HAS_RESOURCE, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Role, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Military_Alliances, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Territorial_Annexation_of_Ukraine, Class: http://www.semanticweb.org/geopoliFirst#Objective
# Individual: http://www.semanticweb.org/geopoliFirst#Timber, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#Imported_Weapons, Class: http://www.semanticweb.org/geopoliFirst#Military
# Individual: http://www.semanticweb.org/geopoliFirst#Bucharest_Summit_2008, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Mountainous, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#sugar_beets, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#domestic, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#EU, Class: http://www.semanticweb.org/geopoliFirst#Organization
# Individual: http://www.semanticweb.org/geopoliFirst#China, Class: http://www.semanticweb.org/geopoliFirst#Country
# Individual: http://www.semanticweb.org/geopoliFirst#Sulfur, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Caucasus, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Elevation_Range, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#missile_systems, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Temperate, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Strategic_Minerals, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#SEEKING_MEMBERSHIP, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Infrastructure, Class: http://www.w3.org/2002/07/owl#Class
# Individual: http://www.semanticweb.org/geopoliFirst#Population_density, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Protected_Areas, Class: http://www.semanticweb.org/geopoliFirst#Environmental_Factors
# Individual: http://www.semanticweb.org/geopoliFirst#Pacific_Ocean, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Himalayas, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Ukrain, Class: http://www.semanticweb.org/geopoliFirst#Country
# Individual: http://www.semanticweb.org/geopoliFirst#Graphite, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#Arctic_Ocean, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#PERCEIVES_AS_HISTORICAL_LANDS, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#air_systems, Class: http://www.w3.org/2002/07/owl#DatatypeProperty
# Individual: http://www.semanticweb.org/geopoliFirst#POSSESSES, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#wheat, Class: http://www.semanticweb.org/geopoliFirst#Resources
# Individual: http://www.semanticweb.org/geopoliFirst#FACES_GEOPOLITICAL_CHALLENGE, Class: http://www.w3.org/2002/07/owl#ObjectProperty
# Individual: http://www.semanticweb.org/geopoliFirst#Grain_Corn, Class: http://www.w3.org/2002/07/owl#NamedIndividual
# Individual: http://www.semanticweb.org/geopoliFirst#Freshwater_Reserves, Class: http://www.semanticweb.org/geopoliFirst#Resources
# ...
# Subject: http://www.semanticweb.org/geopoliFirst#UN_Security_Council, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Organization
# Subject: http://www.semanticweb.org/geopoliFirst#Donbass_War, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Freshwater_Reserves, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Ukrain, Predicate: http://www.semanticweb.org/geopoliFirst#HAS_RESOURCE, Object: http://www.semanticweb.org/geopoliFirst#Gold
# Subject: http://www.semanticweb.org/geopoliFirst#Euromaidan_Protests, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Russian_Government, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Government
# Subject: http://www.semanticweb.org/geopoliFirst#Oil, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#EU, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Organization
# Subject: http://www.semanticweb.org/geopoliFirst#HAS_EQUIPMENT, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Canada, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Country
# Subject: http://www.semanticweb.org/geopoliFirst#capital, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#DatatypeProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Infrastructure, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#Class
# Subject: http://www.semanticweb.org/geopoliFirst#HAS_INFRASTRUCTURE, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Region, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#Class
# Subject: http://www.semanticweb.org/geopoliFirst#President, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#DatatypeProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Continental, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#INFLUENCES, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#UN_Security_Council, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#PREPARES_FOR, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Tsunami, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#EU, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: N7e4a7a305b274634a2d218fc021f667d, Predicate: http://www.w3.org/2002/07/owl#annotatedTarget, Object: http://www.semanticweb.org/geopoliFirst#Discontinuous_Borders
# Subject: http://www.semanticweb.org/geopoliFirst#IS_PART_OF, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#PARTICIPATED_IN, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Salt, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Resources
# Subject: http://www.semanticweb.org/geopoliFirst#Russia, Predicate: http://www.semanticweb.org/geopoliFirst#HAS_RESOURCE, Object: http://www.semanticweb.org/geopoliFirst#Oil
# Subject: http://www.semanticweb.org/geopoliFirst#Coal, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Caucasus, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Geographical_Space
# Subject: N7e4a7a305b274634a2d218fc021f667d, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#Axiom
# Subject: http://www.semanticweb.org/geopoliFirst#Turkish_Straits, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Crimea, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Region
# Subject: http://www.semanticweb.org/geopoliFirst#PROTESTED_IN, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#population, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#DatatypeProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Iron_Ore, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Intensified_Combat, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Event
# Subject: http://www.semanticweb.org/geopoliFirst#wheat, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Resources
# Subject: http://www.semanticweb.org/geopoliFirst#Russian_Weapons, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#land_systems, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#DatatypeProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Ukrain, Predicate: http://www.semanticweb.org/geopoliFirst#HAS_RESOURCE, Object: http://www.semanticweb.org/geopoliFirst#Grain_Corn
# Subject: http://www.semanticweb.org/geopoliFirst#Manganese, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Crimea, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Volodymyr_Zelensky, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Sugar_Beets, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Resources
# Subject: http://www.semanticweb.org/geopoliFirst#HAS_NUCLEAR_REACTORS, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Ukrain, Predicate: http://www.semanticweb.org/geopoliFirst#SEEKING_MEMBERSHIP, Object: http://www.semanticweb.org/geopoliFirst#NATO
# Subject: N9e526473d82549909999c8f6cbff0ef0, Predicate: http://www.w3.org/2002/07/owl#annotatedTarget, Object: http://www.semanticweb.org/geopoliFirst#Caucasus
# Subject: http://www.semanticweb.org/geopoliFirst#Russian_Military, Predicate: http://www.semanticweb.org/geopoliFirst/INCLUDES, Object: http://www.semanticweb.org/geopoliFirst#Russia
# Subject: http://www.semanticweb.org/geopoliFirst#Demographic, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Vladimir_Putin, Predicate: http://www.semanticweb.org/geopoliFirst#INFLUENCES, Object: http://www.semanticweb.org/geopoliFirst#Russian_Intelligence
# Subject: http://www.semanticweb.org/geopoliFirst#Reserve_Forces, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#DatatypeProperty
# Subject: http://www.semanticweb.org/geopoliFirst#PRODUCES, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Ukrain, Predicate: http://www.semanticweb.org/geopoliFirst#HAS_RESOURCE, Object: http://www.semanticweb.org/geopoliFirst#Salt
# Subject: http://www.semanticweb.org/geopoliFirst#Mercury, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Resources
# Subject: http://www.semanticweb.org/geopoliFirst#International_Trade_Sea_Lanes, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Russia, Predicate: http://www.semanticweb.org/geopoliFirst#SEEKS_OBJECTIVE, Object: http://www.semanticweb.org/geopoliFirst#Total_Victory_Over_Ukraine
# Subject: http://www.semanticweb.org/geopoliFirst#Ukrain, Predicate: http://www.semanticweb.org/geopoliFirst#HAS_RESOURCE, Object: http://www.semanticweb.org/geopoliFirst#Sulfur
# Subject: http://www.semanticweb.org/geopoliFirst#Discontinuous_Borders, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Geographical_Space
# Subject: http://www.semanticweb.org/geopoliFirst#Russia, Predicate: http://www.semanticweb.org/geopoliFirst#HAS_RESOURCE, Object: http://www.semanticweb.org/geopoliFirst#Gas
# Subject: http://www.semanticweb.org/geopoliFirst#Ukrainian_Sovereignty, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Natural_Resource_Management, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Environmental_Factors
# Subject: http://www.semanticweb.org/geopoliFirst#Timber, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Resources
# Subject: http://www.semanticweb.org/geopoliFirst#TARGETED_AT, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Ukrain, Predicate: http://www.semanticweb.org/geopoliFirst#RELIES_ON, Object: http://www.semanticweb.org/geopoliFirst#International_Trade_Sea_Lanes
# Subject: http://www.semanticweb.org/geopoliFirst#FACES, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Natural_Resource_Management, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Ukrain, Predicate: http://www.semanticweb.org/geopoliFirst#PROTESTED_IN, Object: http://www.semanticweb.org/geopoliFirst#Euromaidan_Protests
# Subject: http://www.semanticweb.org/geopoliFirst#Eurasian_Flatlands, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Geographical_Space
# Subject: http://www.semanticweb.org/geopoliFirst#Russia, Predicate: http://www.semanticweb.org/geopoliFirst#PRODUCES, Object: http://www.semanticweb.org/geopoliFirst#Sugar_Beets
# Subject: http://www.semanticweb.org/geopoliFirst#Location, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#DatatypeProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Russia, Predicate: http://www.semanticweb.org/geopoliFirst/HAS, Object: http://www.semanticweb.org/geopoliFirst#Arctic_Ocean
# Subject: http://www.semanticweb.org/geopoliFirst#Ukrain, Predicate: http://www.semanticweb.org/geopoliFirst#FACES_BORDER_CHALLENGE, Object: http://www.semanticweb.org/geopoliFirst#Discontinuous_Borders
# Subject: http://www.semanticweb.org/geopoliFirst, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#Ontology
# Subject: http://www.semanticweb.org/geopoliFirst#Ukrainian_Military, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Arctic_Ocean, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Plain, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Russia, Predicate: http://www.semanticweb.org/geopoliFirst#HAS_RESOURCE, Object: http://www.semanticweb.org/geopoliFirst#Coal
# Subject: http://www.semanticweb.org/geopoliFirst#Ukrain, Predicate: http://www.semanticweb.org/geopoliFirst#PARTICIPATED_IN, Object: http://www.semanticweb.org/geopoliFirst#Donbass_War
# Subject: http://www.semanticweb.org/geopoliFirst#Russian_Weapons, Predicate: http://www.semanticweb.org/geopoliFirst#HAS_IMPORT_PARTNER, Object: http://www.semanticweb.org/geopoliFirst#China
# Subject: http://www.semanticweb.org/geopoliFirst#Grain_Corn, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/geopoliFirst#Resources
# Subject: Nd35c1ecade37497bab3204c3456f32d5, Predicate: http://www.w3.org/2002/07/owl#annotatedProperty, Object: http://www.semanticweb.org/geopoliFirst#FACES_BORDER_CHALLENGE
# Subject: http://www.semanticweb.org/geopoliFirst#Vladimir_Putin, Predicate: http://www.semanticweb.org/geopoliFirst#ISSUES_COMMAND_TO, Object: http://www.semanticweb.org/geopoliFirst#Russian_Military
# Subject: http://www.semanticweb.org/geopoliFirst#Russian_Government, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#INVOLVED_IN, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#artillery, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#DatatypeProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Technology, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#Class
# Subject: http://www.semanticweb.org/geopoliFirst#Arable_Land, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual
# Subject: http://www.semanticweb.org/geopoliFirst#Russia, Predicate: http://www.semanticweb.org/geopoliFirst#IS_PART_OF, Object: http://www.semanticweb.org/geopoliFirst#UN_Security_Council
# Subject: http://www.semanticweb.org/geopoliFirst#SIGNED_AGREEMENT_WITH, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#ObjectProperty
# Subject: http://www.semanticweb.org/geopoliFirst#Domestically_Produced_Weapons, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.w3.org/2002/07/owl#NamedIndividual

# %%
import rdflib
from neo4j import GraphDatabase
import re

# Load the RDF graph
ontology_path = "onto.rdf"  # Path to the ontology file
graph = rdflib.Graph()
graph.parse(ontology_path, format="xml")  # Adjust format if necessary

# Connect to Neo4j
uri = "bolt://localhost:7687"  # Neo4j URI
driver = GraphDatabase.driver(uri, auth=("neo4j", "thelastofus"))
session = driver.session()

# Helper function to clean URIs and extract local names
def clean_uri(uri):
    return re.sub(r"[^\w]", "_", uri.split("#")[-1] if "#" in uri else uri.split("/")[-1])

# Helper function to extract the primary class label for a node
def get_primary_class(node):
    valid_classes = []
    for _, _, rdf_type_obj in graph.triples((node, rdflib.RDF.type, None)):
        class_label = clean_uri(rdf_type_obj)
        # Exclude schema-level terms, including NamedIndividual
        if class_label not in {"ObjectProperty", "DataProperty", "DatatypeProperty", "NamedIndividual", "Class", "Axiom", "Ontology"}:
            valid_classes.append(class_label)
    # Prioritize domain-specific classes
    return valid_classes[0] if valid_classes else None

# Iterate through RDF triples
for subj, pred, obj in graph:
    # Skip triples where the subject or predicate does not start with "http"
    if not (str(subj).startswith("http") and str(pred).startswith("http")):
        continue

    # Skip schema-level definitions of DatatypeProperty
    if any(
        rdf_type_obj == rdflib.URIRef("http://www.w3.org/2002/07/owl#DatatypeProperty")
        for _, _, rdf_type_obj in graph.triples((subj, rdflib.RDF.type, None))
    ):
        continue

    # Handle class definitions (rdf:type relationships)
    if str(pred) == "http://www.w3.org/1999/02/22-rdf-syntax-ns#type":
        class_label = clean_uri(obj)
        if class_label not in {"ObjectProperty", "DataProperty", "DatatypeProperty", "NamedIndividual", "Class"}:
            individual_name = clean_uri(subj)
            session.run(
                """
                MERGE (n:{class_label} {{name: $name, uri: $uri}})
                """.format(class_label=class_label),
                name=individual_name,
                uri=str(subj),
            )

    # Handle relationships between nodes
    elif isinstance(obj, rdflib.URIRef):
        subj_name = clean_uri(subj)
        obj_name = clean_uri(obj)
        pred_name = clean_uri(pred)

        subj_class = get_primary_class(subj) or "Entity"
        obj_class = get_primary_class(obj) or "Entity"

        session.run(
            """
            MERGE (a:{subj_class} {{name: $subj_name, uri: $subj_uri}})
            MERGE (b:{obj_class} {{name: $obj_name, uri: $obj_uri}})
            MERGE (a)-[:{rel} {{uri: $rel_uri}}]->(b)
            """.format(subj_class=subj_class, obj_class=obj_class, rel=pred_name),
            subj_name=subj_name,
            subj_uri=str(subj),
            obj_name=obj_name,
            obj_uri=str(obj),
            rel_uri=str(pred),
        )

    # Handle literal values as properties
    elif isinstance(obj, rdflib.Literal):
        property_name = clean_uri(pred)
        individual_name = clean_uri(subj)
        individual_class = get_primary_class(subj) or "Entity"

        session.run(
            """
            MERGE (n:{class_label} {{name: $name, uri: $uri}})
            SET n.{property_name} = $property_value
            """.format(class_label=individual_class, property_name=property_name),
            name=individual_name,
            uri=str(subj),
            property_value=str(obj),
        )

# Close session and driver
session.close()
driver.close()
